# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import requests
import os 
from dotenv import load_dotenv 
load_dotenv() 
from os.path import join, dirname
from dotenv import load_dotenv

# %%
 # conexión con la base de datos de mongo
client = MongoClient("mongodb://localhost:27017/",username='admin',password='123')
db = client.companies

# %%
companies = db.mongonewyork.find()

# %%
data_companies = pd.DataFrame(companies)
data_companies
# Out:
#                         _id               name  \
# 0  5d867fdcc99008113a8662de            PeekYou
# 1  5d867fdcc99008113a8662df      BrandYourself
# 2  5d867fdcc99008113a8662e0      ChallengePost
# 3  5d867fdcc99008113a8662e1              Yipit
# 4  5d867fdcc99008113a8662e2  GameChanger Media
# 5  5d867fdcc99008113a8662e3          Chartbeat
#
#                                             geopoint      City   latitude  \
# 0  {'type': 'Point', 'coordinates': [-73.985506, ...  New York  40.757929
# 1  {'type': 'Point', 'coordinates': [-71.24762, 4...  New York  42.275263
# 2  {'type': 'Point', 'coordinates': [-74.00717, 4...  New York  40.740804
# 3  {'type': 'Point', 'coordinates': [-73.987764, ...  New York  40.744618
# 4  {'type': 'Point', 'coordinates': [-74.0136605,...  New York  40.707834
# 5  {'type': 'Point', 'coordinates': [-73.990967, ...  New York  40.733430
#
#    longitude
# 0 -73.985506
# 1 -71.247620
# 2 -74.007170
# 3 -73.987764
# 4 -74.013661
# 5 -73.990967

# %%
data_ny = data_companies[data_companies["City"].str.contains("New York")]
data_ny
# Out:
#                         _id               name  \
# 0  5d867fdcc99008113a8662de            PeekYou
# 1  5d867fdcc99008113a8662df      BrandYourself
# 2  5d867fdcc99008113a8662e0      ChallengePost
# 3  5d867fdcc99008113a8662e1              Yipit
# 4  5d867fdcc99008113a8662e2  GameChanger Media
# 5  5d867fdcc99008113a8662e3          Chartbeat
#
#                                             geopoint      City   latitude  \
# 0  {'type': 'Point', 'coordinates': [-73.985506, ...  New York  40.757929
# 1  {'type': 'Point', 'coordinates': [-71.24762, 4...  New York  42.275263
# 2  {'type': 'Point', 'coordinates': [-74.00717, 4...  New York  40.740804
# 3  {'type': 'Point', 'coordinates': [-73.987764, ...  New York  40.744618
# 4  {'type': 'Point', 'coordinates': [-74.0136605,...  New York  40.707834
# 5  {'type': 'Point', 'coordinates': [-73.990967, ...  New York  40.733430
#
#    longitude
# 0 -73.985506
# 1 -71.247620
# 2 -74.007170
# 3 -73.987764
# 4 -74.013661
# 5 -73.990967

# %%
path = os.path.abspath('')
dotenv_path = join(dirname(path), '.env')
load_dotenv(dotenv_path)
SECRET_KEY = os.environ.get("api")

# %%
#API Starbucks

#response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=1500&type=restaurant&keyword=cruise&key=YOUR_API_KEY")
#response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.77891,-73.96367&radius=7500&key=AIzaSyAfwzf5dN8ASz9aIoArozMIFetivUEp2Kc")
response = requests.get("https://maps.googleapis.com/maps/api/place/textsearch/json?query=starbucks+in+new+york+city&fields=geometry/location,name&key={}".format(SECRET_KEY))
data = response.json()
#response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=

# %%
data
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCCQEAAGx6VOXrPT452hbDlK0LGfSa7xfs2zPBFtCpv9ENk4NHqJbBl6Npl5bqxpfwzrSmOW7a-OyslGOcp2nYw_3WxF9zv693lXEK9uk7u8Wy19qGGGgyF0iPa7IkUkSGOkJAQj4kZLVnnZI_vzBVB5f7dkinwtT1LBl02iAWAqXKj8kbArlKBreYQInlIG4vkfGC7Pqv1RXZJdd26dAIO_M51xCVeqNRAagp7wjewKXtlDWk3_lruqJNnaokZWKJEg_3_ITBVZQXa1CwsN6mhf0HWfXONUkY0uOD0d-onGSqAh1penzNd3S0JnTJnwstNxUKX7__vquBD1M9Md8pe83fID6RxlYT5x6YPfALAQMhInr7EhDEJzdM0BAoI10PgdJ812uWGhTlZ38m_PCsBOo7bgwIXfFcZwIU2g',
#  'results': [{'formatted_address': '1500 Broadway, New York, NY 10019, USA',
#    'geometry': {'location': {'lat': 40.7567274, 'lng': -73.9858802},
#     'viewport': {'northeast': {'lat': 40.75799997989272,
#       'lng': -73.98462552010727},
#      'southwest': {'lat': 40.75530032010727, 'lng': -73.98732517989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '0670c3bc090a1e37682bc6822528b0fc0686363b',
#    'name': 'Starbucks',
# ...

# %%
def starbucks(dictrandom):
    names=[]
    lats=[]
    long=[]
    for place in dictrandom["results"]:
        names.append(place["name"])
        lats.append(place["geometry"]["location"]["lat"])
        long.append(place["geometry"]["location"]["lng"])
    dictstarbucks = {"name":names, "latitude":lats, "longitude":long}
    return pd.DataFrame(dictstarbucks)
datastarbucks = starbucks(data)
datastarbucks.head()
# Out:
#         name   latitude  longitude
# 0  Starbucks  40.756727 -73.985880
# 1  Starbucks  40.739361 -74.002577
# 2  Starbucks  40.772464 -73.950066
# 3  Starbucks  40.760737 -73.983782
# 4  Starbucks  40.760348 -73.976134

# %%
datastarbucks["City"] = "New York"
datastarbucks.head()
# Out:
#         name   latitude  longitude      City
# 0  Starbucks  40.756727 -73.985880  New York
# 1  Starbucks  40.739361 -74.002577  New York
# 2  Starbucks  40.772464 -73.950066  New York
# 3  Starbucks  40.760737 -73.983782  New York
# 4  Starbucks  40.760348 -73.976134  New York

# %%
def createGeoJson(office):
    return {
        "type":"Point",
        "coordinates":[office["longitude"],office["latitude"]]
    }
datastarbucks['position'] = datastarbucks.apply(createGeoJson, axis=1)

# %%
datastarbucks
# Out:
#                  name   latitude  longitude      City  \
# 0           Starbucks  40.756727 -73.985880  New York
# 1           Starbucks  40.739361 -74.002577  New York
# 2           Starbucks  40.772464 -73.950066  New York
# 3           Starbucks  40.760737 -73.983782  New York
# 4           Starbucks  40.760348 -73.976134  New York
# 5           Starbucks  40.762401 -73.974057  New York
# 6   Starbucks Reserve  40.714152 -74.015532  New York
# 7           Starbucks  40.757135 -73.989148  New York
# 8           Starbucks  40.758856 -73.978954  New York
# 9           Starbucks  40.763714 -73.985313  New York
# 10          Starbucks  40.711619 -74.006730  New York
# 11          Starbucks  40.755599 -73.980208  New York
# 12          Starbucks  40.718252 -73.999961  New York
# 13          Starbucks  40.705162 -74.011330  New York
# 14          Starbucks  40.710910 -74.010363  New York
# 15          Starbucks  40.764412 -73.981069  New York
# ...

# %%
datastarbucks.to_json('./mongostarbucks.json',orient="records")
